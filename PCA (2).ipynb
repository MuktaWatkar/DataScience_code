# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from sklearn.preprocessing import scale
import seaborn as sns

# %%
wine=pd.read_csv("D:/ASSIGNMENTS/A8 PCA/wine.csv")
wine.describe()
wine.head()
# Out:
#    Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0     1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1     1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2     1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3     1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4     1    13.24   2.59  2.87        21.0        118     2.80        2.69
#
#    Nonflavanoids  Proanthocyanins  Color   Hue  Dilution  Proline
# 0           0.28             2.29   5.64  1.04      3.92     1065
# 1           0.26             1.28   4.38  1.05      3.40     1050
# 2           0.30             2.81   5.68  1.03      3.17     1185
# 3           0.24             2.18   7.80  0.86      3.45     1480
# 4           0.39             1.82   4.32  1.04      2.93      735

# %%
data=wine.iloc[:,1:]

# %%
data=wine.values
data
# Out:
# array([[1.000e+00, 1.423e+01, 1.710e+00, ..., 1.040e+00, 3.920e+00,
#         1.065e+03],
#        [1.000e+00, 1.320e+01, 1.780e+00, ..., 1.050e+00, 3.400e+00,
#         1.050e+03],
#        [1.000e+00, 1.316e+01, 2.360e+00, ..., 1.030e+00, 3.170e+00,
#         1.185e+03],
#        ...,
#        [3.000e+00, 1.327e+01, 4.280e+00, ..., 5.900e-01, 1.560e+00,
#         8.350e+02],
#        [3.000e+00, 1.317e+01, 2.590e+00, ..., 6.000e-01, 1.620e+00,
#         8.400e+02],
#        [3.000e+00, 1.413e+01, 4.100e+00, ..., 6.100e-01, 1.600e+00,
#         5.600e+02]])

# %%
data_normal=scale(data)

# %%
pca=PCA()
pca_values=pca.fit_transform(data_normal)

# %%
pca_values
# Out:
# array([[-3.52293390e+00, -1.45309844e+00, -1.64795488e-01, ...,
#          5.52927766e-01, -3.02978176e-01,  2.00857450e-01],
#        [-2.52885806e+00,  3.30019252e-01, -2.02670665e+00, ...,
#          3.94971160e-01, -1.46645308e-01,  1.26402355e-01],
#        [-2.78502898e+00, -1.03693595e+00,  9.83237703e-01, ...,
#          1.89799314e-03,  2.12780166e-02, -5.57515155e-02],
#        ...,
#        [ 3.02727243e+00, -2.75604024e+00, -9.40803036e-01, ...,
#          6.93336340e-01,  1.67035660e-01, -3.16957430e-02],
#        [ 2.75522166e+00, -2.29378408e+00, -5.50473677e-01, ...,
#          3.44119826e-01, -1.09514873e-01,  1.02823104e-01],
#        [ 3.49633565e+00, -2.76060799e+00,  1.01315115e+00, ...,
#         -1.89866131e-01, -1.64090011e-01, -2.64916504e-01]])

# %%
pca=PCA(n_components=6)
pca_values=pca.fit_transform(data_normal)

# %%
pca_values
# Out:
# array([[-3.5229339 , -1.45309844, -0.16479549, -0.01327282,  0.73734536,
#         -0.30071618],
#        [-2.52885806,  0.33001925, -2.02670665, -0.41714436, -0.28321373,
#         -0.88430941],
#        [-2.78502898, -1.03693595,  0.9832377 ,  0.66423241, -0.38756497,
#          0.46884161],
#        ...,
#        [ 3.02727243, -2.75604024, -0.94080304,  0.60775846,  1.12813634,
#          0.00529036],
#        [ 2.75522166, -2.29378408, -0.55047368, -0.39157042,  1.06708304,
#          1.01256231],
#        [ 3.49633565, -2.76060799,  1.01315115,  0.3496303 , -1.00513627,
#          0.37722337]])

# %%
var=pca.explained_variance_ratio_
var
# Out:
# array([0.39542486, 0.17836259, 0.10329102, 0.06627984, 0.06267875,
#        0.0480556 ])

# %%
varcum=np.cumsum(np.round(var,decimals=4)*100)
varcum
# Out:
# array([39.54, 57.38, 67.71, 74.34, 80.61, 85.42])

# %%
plt.plot(varcum)

# %%
pca_values[:,0:1]
# Out:
# array([[-3.5229339 ],
#        [-2.52885806],
#        [-2.78502898],
#        [-3.92258841],
#        [-1.40751111],
#        [-3.28812981],
#        [-2.75057754],
#        [-2.39286652],
#        [-2.79525633],
#        [-3.00559666],
#        [-3.67868855],
#        [-2.10963477],
#        [-2.43845636],
#        [-3.67349453],
#        [-4.44157575],
#        [-2.60892387],
#        [-2.47542846],
#        [-2.22623243],
#        [-3.74226929],
#        [-2.3944115 ],
#        [-3.33656895],
#        [-1.48140399],
#        [-2.82806867],
#        [-2.00771405],
#        [-2.11463604],
#        [-1.39753751],
#        [-2.13348803],
#        [-1.62970383],
#        [-2.50760753],
#        [-2.55948318],
#        [-2.77244452],
#        [-2.93513374],
#        [-1.99124842],
#        [-2.24570987],
#        [-1.78698628],
#        [-2.22763867],
#        [-1.76802847],
#        [-1.52317798],
#        [-1.87236494],
#        [-2.79711434],
#        [-2.84093569],
# ...

# %%
x=pca_values[:,0:1]
y=pca_values[:,1:2]
plt.scatter(x,y)

# %%
final_df=pd.concat([pd.DataFrame(pca_values[:,0:6],columns=['pc1','pc2','pc3','pc4','pc5','pc6']),wine[['Type']]],axis=1)
final_df
# Out:
#           pc1       pc2       pc3       pc4       pc5       pc6  Type
# 0   -3.522934 -1.453098 -0.164795 -0.013273  0.737345 -0.300716     1
# 1   -2.528858  0.330019 -2.026707 -0.417144 -0.283214 -0.884309     1
# 2   -2.785029 -1.036936  0.983238  0.664232 -0.387565  0.468842     1
# 3   -3.922588 -2.768210 -0.174968  0.565088 -0.324360  0.262616     1
# 4   -1.407511 -0.867773  2.025829 -0.440906  0.227949 -0.593762     1
# ..        ...       ...       ...       ...       ...       ...   ...
# 173  3.627996 -2.206617 -0.343668  0.751705 -1.004109 -1.143155     3
# 174  2.942729 -1.752263  0.207480  0.399381  0.154223 -0.062465     3
# 175  3.027272 -2.756040 -0.940803  0.607758  1.128136  0.005290     3
# 176  2.755222 -2.293784 -0.550474 -0.391570  1.067083  1.012562     3
# 177  3.496336 -2.760608  1.013151  0.349630 -1.005136  0.377223     3
#
# [178 rows x 7 columns]

# %%
sns.scatterplot(data=final_df,x="pc1",y='pc2',hue='Type')
# Out:
# <AxesSubplot:xlabel='pc1', ylabel='pc2'>

# %%
import scipy.cluster.hierarchy as sch
dendrogram=sch.dendrogram(sch.linkage(pca_values,method='complete'))

# %%
from sklearn.cluster import KMeans
from scipy.spatial.distance import cdist

# %%
model=KMeans(n_clusters=5)
model.fit(pca_values)
model.labels_
cluster=pd.DataFrame(model.labels_,columns=['Cluster'])
cluster
# Out:
#      Cluster
# 0          4
# 1          4
# 2          4
# 3          4
# 4          3
# ..       ...
# 173        1
# 174        1
# 175        1
# 176        1
# 177        1
#
# [178 rows x 1 columns]

# %%
wine['cluster']=pd.DataFrame(cluster)
wine
# Out:
#      Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0       1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1       1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2       1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3       1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4       1    13.24   2.59  2.87        21.0        118     2.80        2.69
# ..    ...      ...    ...   ...         ...        ...      ...         ...
# 173     3    13.71   5.65  2.45        20.5         95     1.68        0.61
# 174     3    13.40   3.91  2.48        23.0        102     1.80        0.75
# 175     3    13.27   4.28  2.26        20.0        120     1.59        0.69
# 176     3    13.17   2.59  2.37        20.0        120     1.65        0.68
# 177     3    14.13   4.10  2.74        24.5         96     2.05        0.76
#
# ...

# %%
final=wine.iloc[:,1:].groupby(wine.cluster).mean()
final
# Out:
#            Alcohol     Malic       Ash  Alcalinity   Magnesium   Phenols  \
# cluster
# 0        12.258333  1.842778  2.073889   18.513889   92.527778  2.437500
# 1        13.151633  3.344490  2.434694   21.438776   99.020408  1.678163
# 2        12.218667  2.009000  2.390000   21.513333   93.033333  1.968333
# 3        13.362000  1.898500  2.707000   20.535000  114.100000  2.764000
# 4        13.827442  2.032791  2.359070   16.209302  104.604651  2.888837
#
#          Flavanoids  Nonflavanoids  Proanthocyanins     Color       Hue  \
# cluster
# 0          2.258056       0.289444         1.798333  3.133056  1.047500
# 1          0.797959       0.450816         1.163061  7.343265  0.685918
# 2          1.725333       0.452667         1.347000  2.874333  1.056200
# 3          2.860500       0.333500         1.786500  4.764000  1.142000
# 4          3.066279       0.270930         1.983953  5.726047  1.036744
#
#          Dilution      Proline  cluster
# cluster
# ...
